# %% [markdown]
# # STEP 6: Calculate zonal statistics
#
# In order to evaluate the connection between vegetation health and
# redlining, we need to summarize NDVI across the same geographic areas as
# we have redlining information.
#
# First, import variables from previous notebooks:

# %%
store -r denver_proj_aoi_gdf denver_ndvi_da

# %%
denver_proj_aoi_gdf
# Out:
#       area_id    city state  city_surve              category grade  \
# 1103     6525  Denver    CO        True                  Best     A
# 1104     6529  Denver    CO        True                  Best     A
# 1105     6537  Denver    CO        True                  Best     A
# 1106     6536  Denver    CO        True                  Best     A
# 1107     6540  Denver    CO        True                  Best     A
# 1108     6550  Denver    CO        True                  Best     A
# 1109     6526  Denver    CO        True       Still Desirable     B
# 1110     6562  Denver    CO        True       Still Desirable     B
# 1111     6564  Denver    CO        True       Still Desirable     B
# 1112     6567  Denver    CO        True       Still Desirable     B
# 1113     6527  Denver    CO        True       Still Desirable     B
# 1114     6528  Denver    CO        True       Still Desirable     B
# 1115     6524  Denver    CO        True       Still Desirable     B
# 1116     6535  Denver    CO        True       Still Desirable     B
# 1117     6541  Denver    CO        True       Still Desirable     B
# 1118     6542  Denver    CO        True       Still Desirable     B
# 1119     6549  Denver    CO        True       Still Desirable     B
# 1120     6552  Denver    CO        True       Still Desirable     B
# 1121     6523  Denver    CO        True  Definitely Declining     C
# 1122     6545  Denver    CO        True  Definitely Declining     C
# 1123     6546  Denver    CO        True  Definitely Declining     C
# 1124     6544  Denver    CO        True  Definitely Declining     C
# 1125     6547  Denver    CO        True  Definitely Declining     C
# 1126     6551  Denver    CO        True  Definitely Declining     C
# 1127     6571  Denver    CO        True  Definitely Declining     C
# 1128     6561  Denver    CO        True  Definitely Declining     C
# 1129     6563  Denver    CO        True  Definitely Declining     C
# 1130     6565  Denver    CO        True  Definitely Declining     C
# 1131     6569  Denver    CO        True  Definitely Declining     C
# 1132     6530  Denver    CO        True  Definitely Declining     C
# 1133     6570  Denver    CO        True  Definitely Declining     C
# 1134     6575  Denver    CO        True  Definitely Declining     C
# 1135     6574  Denver    CO        True  Definitely Declining     C
# 1136     6534  Denver    CO        True  Definitely Declining     C
# 1137     6533  Denver    CO        True  Definitely Declining     C
# 1138     6573  Denver    CO        True  Definitely Declining     C
# 1139     6543  Denver    CO        True  Definitely Declining     C
# 1140     6539  Denver    CO        True  Definitely Declining     C
# 1141     6522  Denver    CO        True             Hazardous     D
# 1142     6568  Denver    CO        True             Hazardous     D
# 1143     6555  Denver    CO        True             Hazardous     D
# 1144     6531  Denver    CO        True             Hazardous     D
# 1145     6532  Denver    CO        True             Hazardous     D
# 1146     6557  Denver    CO        True             Hazardous     D
# 1147     6556  Denver    CO        True             Hazardous     D
# 1148     6553  Denver    CO        True             Hazardous     D
# 1149     6538  Denver    CO        True             Hazardous     D
# 1150     6548  Denver    CO        True             Hazardous     D
# 1151     6572  Denver    CO        True             Hazardous     D
# 1152     6554  Denver    CO        True             Hazardous     D
# 1153     6558  Denver    CO        True             Hazardous     D
# 1154     6559  Denver    CO        True             Hazardous     D
# 1155     6560  Denver    CO        True             Hazardous     D
# 1156     6566  Denver    CO        True             Hazardous     D
# 1157    11170  Denver    CO        True            Commercial  None
# 1158    11171  Denver    CO        True            Industrial  None
#
#            label  residentia  commercial  industrial     fill  \
# 1103          A1        True       False       False  #76a865
# 1104          A2        True       False       False  #76a865
# 1105          A3        True       False       False  #76a865
# 1106          A4        True       False       False  #76a865
# 1107          A5        True       False       False  #76a865
# 1108          A6        True       False       False  #76a865
# 1109          B1        True       False       False  #7cb5bd
# 1110         B10        True       False       False  #7cb5bd
# 1111         B11        True       False       False  #7cb5bd
# 1112         B12        True       False       False  #7cb5bd
# 1113          B2        True       False       False  #7cb5bd
# 1114          B3        True       False       False  #7cb5bd
# 1115          B4        True       False       False  #7cb5bd
# 1116          B5        True       False       False  #7cb5bd
# 1117          B6        True       False       False  #7cb5bd
# 1118          B7        True       False       False  #7cb5bd
# 1119          B8        True       False       False  #7cb5bd
# 1120          B9        True       False       False  #7cb5bd
# 1121          C1        True       False       False  #ffff00
# 1122         C10        True       False       False  #ffff00
# 1123         C11        True       False       False  #ffff00
# 1124         C12        True       False       False  #ffff00
# 1125         C13        True       False       False  #ffff00
# 1126         C14        True       False       False  #ffff00
# 1127         C15        True       False       False  #ffff00
# 1128         C16        True       False       False  #ffff00
# 1129         C17        True       False       False  #ffff00
# 1130         C18        True       False       False  #ffff00
# 1131         C19        True       False       False  #ffff00
# 1132          C2        True       False       False  #ffff00
# 1133         C20        True       False       False  #ffff00
# 1134          C3        True       False       False  #ffff00
# 1135          C4        True       False       False  #ffff00
# 1136          C5        True       False       False  #ffff00
# 1137          C6        True       False       False  #ffff00
# 1138          C7        True       False       False  #ffff00
# 1139          C8        True       False       False  #ffff00
# 1140          C9        True       False       False  #ffff00
# 1141          D1        True       False       False  #d9838d
# 1142         D10        True       False       False  #d9838d
# 1143         D11        True       False       False  #d9838d
# 1144         D12        True       False       False  #d9838d
# 1145         D13        True       False       False  #d9838d
# 1146         D14        True       False       False  #d9838d
# 1147         D15        True       False       False  #d9838d
# 1148         D16        True       False       False  #d9838d
# 1149          D2        True       False       False  #d9838d
# 1150          D3        True       False       False  #d9838d
# 1151          D4        True       False       False  #d9838d
# 1152          D5        True       False       False  #d9838d
# 1153          D6        True       False       False  #d9838d
# 1154          D7        True       False       False  #d9838d
# 1155          D8        True       False       False  #d9838d
# 1156          D9        True       False       False  #d9838d
# 1157  Commercial       False        True       False  #000000
# 1158  Industrial       False       False        True  #000000
#
#                                                geometry
# 1103  POLYGON ((-11678320.725 4801996.92, -11678331....
# 1104  POLYGON ((-11679886.99 4800694.801, -11679894....
# 1105  POLYGON ((-11678840.587 4798801.771, -11679394...
# 1106  POLYGON ((-11684111.565 4799342.393, -11684111...
# 1107  POLYGON ((-11684044.773 4798553.815, -11684034...
# 1108  POLYGON ((-11683373.517 4794663.745, -11683509...
# 1109  POLYGON ((-11680543.775 4802094.983, -11680553...
# 1110  POLYGON ((-11692920.276 4801483.55, -11692542....
# 1111  POLYGON ((-11694407.504 4804158.848, -11693437...
# 1112  POLYGON ((-11691364.03 4804269.914, -11691407....
# 1113  POLYGON ((-11680543.775 4802094.983, -11680668...
#          0.4332443 ,  0.60560626],
#        [ 0.56208944,  0.53956836,  0.58609277, ...,  0.4952128 ,
#          0.54162043,  0.5768989 ],
#        ...,
#        [-0.44827586, -0.46341464, -0.5128205 , ...,  0.49735266,
#          0.6539264 ,  0.69990563],
#        [-0.44578314, -0.46341464, -0.4933333 , ...,  0.62182057,
#          0.7494679 ,  0.7715995 ],
#        [-0.5064935 , -0.48717952, -0.5277778 , ...,  0.6248052 ,
#          0.67142856,  0.65192586]], dtype=float32)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#     spatial_ref  int64 8B 0

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: Import packages</div></div><div class="callout-body-container callout-body"><p>Some packages are included that will help you calculate statistics
# for areas imported below. Add packages for:</p>
# <ol type="1">
# <li>Interactive plotting of tabular and vector data</li>
# <li>Working with categorical data in <code>DataFrame</code>s</li>
# </ol></div></div>

# %%
# Interactive plots with pandas
# Ordered categorical data
import regionmask # Convert shapefile to mask
from xrspatial import zonal_stats # Calculate zonal statistics

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: Convert vector to raster</div></div><div class="callout-body-container callout-body"><p>You can convert your vector data to a raster mask using the
# <code>regionmask</code> package. You will need to give
# <code>regionmask</code> the geographic coordinates of the grid you are
# using for this to work:</p>
# <ol type="1">
# <li>Replace <code>gdf</code> with your redlining
# <code>GeoDataFrame</code>.</li>
# <li>Add code to put your <code>GeoDataFrame</code> in the same CRS as
# your raster data.</li>
# <li>Replace <code>x_coord</code> and <code>y_coord</code> with the x and
# y coordinates from your raster data.</li>
# </ol></div></div>

# %%
denver_redlining_mask = regionmask.mask_geopandas(
    denver_proj_aoi_gdf,
    denver_proj_aoi_gdf.geometry, 
    504,447,
    # The regions do not overlap
    overlap=False,
    # We're not using geographic coordinates
    wrap_lon=False
)
# Out:
# C:\Users\gpaul\AppData\Local\Temp\ipykernel_6356\1319720303.py:1: FutureWarning: Passing 'lon_name' as positional argument(s) to mask_geopandas was deprecated in version 0.10.0 and will raise an error two releases later. Please pass them as keyword arguments.
#   denver_redlining_mask = regionmask.mask_geopandas(
# c:\Users\gpaul\miniconda3\envs\earth-analytics-python\Lib\site-packages\regionmask\core\mask.py:179: FutureWarning: Passing 'lon_name' and 'lat_name' was deprecated in v0.10.0. Please pass the coordinates directly, e.g., `mask*(ds[lon_name], ds[lat_name])`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 denver_redlining_mask = regionmask.mask_geopandas(
#       2     denver_proj_aoi_gdf,
#       3     denver_proj_aoi_gdf.geometry,
#       4     504,447,
#       5     # The regions do not overlap
#       6     overlap=False,
#       7     # We're not using geographic coordinates
#       8     wrap_lon=False
#       9 )
#
# File c:\Users\gpaul\miniconda3\envs\earth-analytics-python\Lib\site-packages\regionmask\core\_deprecate.py:106, in _deprecate_positional_args.<locals>._decorator.<locals>.inner(*args, **kwargs)
#     103     zip_args = zip(kwonly_args[:n_extra_args], args[-n_extra_args:])
#     104     kwargs.update({name: arg for name, arg in zip_args})
# --> 106     return func(*args[:-n_extra_args], **kwargs)
#     108 return func(*args, **kwargs)
#
# File c:\Users\gpaul\miniconda3\envs\earth-analytics-python\Lib\site-packages\regionmask\core\_geopandas.py:240, in mask_geopandas(geodataframe, lon_or_obj, lat, lon_name, lat_name, numbers, method, wrap_lon, use_cf, overlap)
#     232     raise ValueError(
#     233         "Creating a 2D mask with overlapping regions yields wrong results. "
#     234         "Please use ``mask_3D_geopandas(...)`` instead. "
#     235         "To create a 2D mask anyway, set ``overlap=False``."
#     236     )
#     238 polygons, numbers = _prepare_gdf_for_mask(geodataframe, numbers=numbers)
# --> 240 return _mask_2D(
#     241     polygons=polygons,
#     242     numbers=numbers,
#     243     lon_or_obj=lon_or_obj,
#     244     lat=lat,
#     245     lon_name=lon_name,
#     246     lat_name=lat_name,
#     247     method=method,
#     248     wrap_lon=wrap_lon,
#     249     overlap=overlap,
#     250     use_cf=use_cf,
#     251 )
#
# File c:\Users\gpaul\miniconda3\envs\earth-analytics-python\Lib\site-packages\regionmask\core\mask.py:383, in _mask_2D(polygons, numbers, lon_or_obj, lat, lon_name, lat_name, method, wrap_lon, use_cf, overlap)
#     358 def _mask_2D(
#     359     polygons,
#     360     numbers,
#    (...)
#     379
#     380     # if as_3D is not explicitly given - set it to True
#     381     as_3D = overlap is None
# --> 383     mask = _mask(
#     384         polygons=polygons,
#     385         numbers=numbers,
#     386         lon_or_obj=lon_or_obj,
#     387         lat=lat,
#     388         lon_name=lon_name,
#     389         lat_name=lat_name,
#     390         method=method,
#     391         wrap_lon=wrap_lon,
#     392         use_cf=use_cf,
#     393         as_3D=as_3D,
#     394     )
#     396     # only happens for (overlap == None)
#     397     if as_3D:
#
# File c:\Users\gpaul\miniconda3\envs\earth-analytics-python\Lib\site-packages\regionmask\core\mask.py:208, in _mask(polygons, numbers, lon_or_obj, lat, lon_name, lat_name, method, wrap_lon, as_3D, use_cf)
#     202     if has_radians and wrap_lon is not False:
#     203         warnings.warn(
#     204             "lon or lat is given as 'radian' (see the 'units' attrs). Should they "
#     205             "be converted to degree?"
#     206         )
# --> 208 lon_arr = np.asarray(lon, dtype=float)
#     209 lat_arr = np.asarray(lat, dtype=float)
#     211 # automatically detect whether wrapping is necessary
#
# File c:\Users\gpaul\miniconda3\envs\earth-analytics-python\Lib\site-packages\pandas\core\series.py:1031, in Series.__array__(self, dtype, copy)
#     981 """
#     982 Return the values as a NumPy array.
#     983
#    (...)
#    1028       dtype='datetime64[ns]')
#    1029 """
#    1030 values = self._values
# -> 1031 arr = np.asarray(values, dtype=dtype)
#    1032 if using_copy_on_write() and astype_is_view(values.dtype, arr.dtype):
#    1033     arr = arr.view()
#
# TypeError: float() argument must be a string or a real number, not 'Polygon'

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: Calculate zonal statistics</div></div><div class="callout-body-container callout-body"><p>Calculate zonal status using the <code>zonal_stats()</code> function.
# To figure out which arguments it needs, use either the
# <code>help()</code> function in Python, or search the internet.</p></div></div>

# %%
# Calculate NDVI stats for each redlining zone

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: Plot regional statistics</div></div><div class="callout-body-container callout-body"><p>Plot the regional statistics:</p>
# <ol type="1">
# <li>Merge the NDVI values into the redlining
# <code>GeoDataFrame</code>.</li>
# <li>Use the code template below to convert the <code>grade</code> column
# (<code>str</code> or <code>object</code> type) to an ordered
# <code>pd.Categorical</code> type. This will let you use ordered color
# maps with the grade data!</li>
# <li>Drop all <code>NA</code> grade values.</li>
# <li>Plot the NDVI and the redlining grade next to each other in linked
# subplots.</li>
# </ol></div></div>

# %%
# Merge the NDVI stats with redlining geometry into one `GeoDataFrame`

# Change grade to ordered Categorical for plotting
gdf.grade = pd.Categorical(
    gdf.grade,
    ordered=True,
    categories=['A', 'B', 'C', 'D']
)

# Drop rows with NA grades
denver_ndvi_gdf = denver_ndvi_gdf.dropna()

# Plot NDVI and redlining grade in linked subplots

# %%
store denver_ndvi_gdf
